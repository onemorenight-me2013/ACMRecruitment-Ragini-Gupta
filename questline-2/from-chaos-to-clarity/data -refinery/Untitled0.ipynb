# %% [markdown]
# <a href="https://colab.research.google.com/github/onemorenight-me2013/ACMRecruitment-Ragini-Gupta/blob/main/questline-2/from-chaos-to-clarity/data%20-refinery/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


df=pd.read_csv("StudentsPerformance.csv")
print("Duplicate rows count:", df.duplicated().sum())

# Drop duplicates
df = df.drop_duplicates()
print("Shape after dropping duplicates:", df.shape)
# Out:
# Duplicate rows count: 0
# Shape after dropping duplicates: (1000, 8)
